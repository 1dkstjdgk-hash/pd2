# %%
# 1번
license_plate = "123 가 9876"
print(license_plate[6:])

#2번
a = "90,123,876,998"
b = a.replace(",","")
print(b)

#3번

fruit_list = ['apple','pineapple','banana','grapes','strawberry']
fruit_list.insert(3,'orange')
print(fruit_list)

#4번

a = [100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110]
print(a[0::2])

#5번

h = ('a', 'b', 'c')

h_list = list(h)

h_list[0] = '1'
h_list[1] = '2'

h_tuple = tuple(h_list)
print(h_tuple)

#6번

inventory = {"메로나": [300, 200], "비비빅": [400, 3], "죠스바": [250, 100]}
print(list(inventory.keys()))

#7번

num = int(input("0보다 큰 정수를 입력하세요 : "))
if num%2 ==0:
    print("짝수입니다")

else:
    print("홀수입니다")


#8번

num_grade = int(input("점수를 입력하세요"))
if num_grade>=91 and num_grade<=100 :
    print("grade A")

elif num_grade >=81 and num_grade <=90 :
    print("grade B")

elif num_grade >=71 and num_grade <=80 :
    print("grade C")

elif num_grade >=61 and num_grade <=70 :
    print("grade D")

elif num_grade <=60 and num_grade>=0:
    print("grade E")

else :
    print("오류입니다.")


#9번

address = "http://www.daum.net"

address_2 = address.replace("http://www.","")

address_2 = address_2[:address_2.index(".")]
print(address_2)

#10번

from random import *
temp = randrange(1,101)
ct = 1
ab = 0
while ct ==21 :

 for i in temp :
        if i >=40 and i <=60 :
         print(f"[O] {ct}번째 숫자는 {i} 이며, 범위내에 있습니다.")
         ab = ab+ 1
         ct = ct+ 1

        else:
         print(f"[X] {ct}번째 숫자는 {i}이며, 범위밖에 있습니다. ")
         ct = ct+ 1

print(f"범위내의 숫자는 총 {ab}번 나왔습니다")
# Out:
# 9876
# 90123876998
# ['apple', 'pineapple', 'banana', 'orange', 'grapes', 'strawberry']
# [100, 102, 104, 106, 108, 110]
# ('1', '2', 'c')
# ['메로나', '비비빅', '죠스바']
# 홀수입니다
# grade E
# daum
# 범위내의 숫자는 총 0번 나왔습니다
