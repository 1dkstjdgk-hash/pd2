# %%
numbers = [273, 103, 5, 32, 65, 9, 72, 800, 99]

for i in numbers:
    if (i%2 == 0):
        print( i, "는 짝수")

    else:
        print( i, "는 홀수")
# Out:
# 273 는 홀수
# 103 는 홀수
# 5 는 홀수
# 32 는 짝수
# 65 는 홀수
# 9 는 홀수
# 72 는 짝수
# 800 는 짝수
# 99 는 홀수
