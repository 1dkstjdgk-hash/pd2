# %%
sec=1 
min= sec*60  

seconds_per_hour = 60*min

seconds_per_day = seconds_per_hour*24

print(seconds_per_hour,"\n")
print(seconds_per_day,"\n")
print(seconds_per_day/seconds_per_hour,"\n")
print(seconds_per_day//seconds_per_hour,"\n")
# Out:
# 3600
#
# 86400
#
# 24.0
#
# 24

# %%
num = int(input("입력받기:"))
if num%3 == 0 :
    print("3의 배수이다")

else :
    print("3의 배수가 아니다")
# Out:
# 3의 배수이다

# %%
coffee = ['americano','caffelatte','espresso']
coffe_price = [3000,4000,1500]

print(coffee[0],'는 ',coffe_price[0],'원이다')
print(coffee[1],'는 ',coffe_price[1],'원이다')
print(coffee[2],'는 ',coffe_price[2],'원이다')
# Out:
# americano 는  3000 원이다
# caffelatte 는  4000 원이다
# espresso 는  1500 원이다

# %%
a= int(input())
print(a)
# Out:
# 3

# %%
a = int(input())

if a>3 :
    if (a%2==0 or a%3==0) :
        print("소수가 아닙니다")
        
    else:
        print("소수입니다")

elif a ==2:
    print("소수입니다")

else:
    print("소수가 아닙니다.")
